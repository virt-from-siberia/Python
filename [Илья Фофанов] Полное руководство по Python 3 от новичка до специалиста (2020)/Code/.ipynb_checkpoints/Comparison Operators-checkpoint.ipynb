# %%
2 > 1
# Out:
# True

# %%
result = 2 > 1
type(result)
# Out:
# bool

# %%
print(2 > 2)
print(2 >= 2)
print(3 >= 2)
print(3 >= 4)
# Out:
# False
# True
# True
# False

# %%
print(2 < 3)
print(3 < 2)
print(3 <= 3)
print(3 <= 2)
print(3 <= 4)
# Out:
# True
# False
# True
# False
# True

# %%
1==1
# Out:
# True

# %%
#1=1

# %%
print("string" == "string")
print("string" == "another string")
print("String" == "string")
x = "String"
y = "string"
print(x.lower() == y.lower())
# Out:
# True
# False
# False
# True

# %%
#is

# %%
1 != 1
# Out:
# False

# %%
2 != 1
# Out:
# True

# %% [markdown]
# Chaining

# %%
1 < 2
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 and 2 < 3
# Out:
# True
